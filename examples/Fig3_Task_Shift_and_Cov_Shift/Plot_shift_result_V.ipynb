# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data_shift_V = pd.read_csv("testdistribution_V.csv",index_col=False)
left_right_pairs = [[1,2], [2,3], [3,5], [5,10], [10,20]]

# %%
data_shift_V
# Out:
#      Unnamed: 0  index  seed  alpha  tau  v_l  v_r   d    n  N_train  N_test  \
# 0             0      0   300      3    5    1    2  50  300     5000    1000
# 1             1      0   300      3    5    1    2  50  300     5000    1000
# 2             2      0   300      3    5    1    2  50  300     5000    1000
# 3             3      0   300      3    5    1    2  50  300     5000    1000
# 4             4      0   300      3    5    1    2  50  300     5000    1000
# ..          ...    ...   ...    ...  ...  ...  ...  ..  ...      ...     ...
# 170         170      4  4300      3    5   10   20  50  300     5000    1000
# 171         171      4  4300      3    5   10   20  50  300     5000    1000
# 172         172      4  4300      3    5   10   20  50  300     5000    1000
# 173         173      4  4300      3    5   10   20  50  300     5000    1000
# 174         174      4  4300      3    5   10   20  50  300     5000    1000
#
# ...

# %%
f, ax = plt.subplots(figsize=(6,6))
sns.lineplot(data=data_shift_V[data_shift_V["n"]==300], x="m",y="err_h1_relative",err_style="bars",markers=True, hue="index",style="index",linewidth=2, palette="coolwarm") #sns.color_palette("husl"))

ax.set(xscale="log", yscale="log")
legend = plt.legend(fontsize=12, loc = 1)
i = 0
for text in legend.texts:    
    text.set_text(r"$V(x)\sim \mathbf{U}(" + str(left_right_pairs[i][0]) + ", " + str(str(left_right_pairs[i][1])) + ")$")
    i += 1

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel("Context Length (m)", fontsize=20)
plt.ylabel("Relative H1 Error", fontsize=20)
plt.title("d=50, n=300", fontsize=20)
# Out:
# Text(0.5, 1.0, 'd=50, n=300')

# %%
f, ax = plt.subplots(figsize=(6,6))
sns.lineplot(data=data_shift_V[data_shift_V["n"]==300], x="m",y="err_l2_relative",err_style="bars",markers=True, hue="index",style="index",linewidth=2, palette="coolwarm") #sns.color_palette("husl"))

ax.set(xscale="log", yscale="log")

legend = plt.legend(fontsize=12, loc = 1)
i = 0
for text in legend.texts:    
    text.set_text(r"$V(x)\sim \mathbf{U}(" + str(left_right_pairs[i][0]) + ", " + str(str(left_right_pairs[i][1])) + ")$")
    i += 1
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel("Context Length (m)", fontsize=20)
plt.ylabel("Relative L2 Error", fontsize=20)
plt.title("d=50, n=300", fontsize=20)
# Out:
# Text(0.5, 1.0, 'd=50, n=300')

# %%
f, ax = plt.subplots(figsize=(6,6))
sns.lineplot(data=data_shift_V[data_shift_V["n"]==300], x="m",y="err_l2_coeff",err_style="bars",markers=True, hue="index",style="index",linewidth=2, palette="coolwarm") #sns.color_palette("husl"))

ax.set(xscale="log", yscale="log")
legend = plt.legend(fontsize=12, loc = 1)
i = 0
for text in legend.texts:    
    text.set_text(r"$V(x)\sim \mathbf{U}(" + str(left_right_pairs[i][0]) + ", " + str(str(left_right_pairs[i][1])) + ")$")
    i += 1
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel("Context Length (m)", fontsize=20)
plt.ylabel("L2 Error (Coefficient)", fontsize=20)
plt.title("d=50, n=300", fontsize=20)
# Out:
# Text(0.5, 1.0, 'd=50, n=300')
